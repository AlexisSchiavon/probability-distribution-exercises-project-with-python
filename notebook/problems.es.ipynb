# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
# Distribución normal
from scipy.stats import norm
import numpy as np


def dnorm(n, mu= 0, s = 1):
    """
    Calcula la estimación puntual de la distribución normal.
    """
    result = norm.pdf(x = n, loc = mu, scale = s)

    return result

def pnorm(n, mu = 0, s = 1):
    """
    Calcula el acumulado de la distribución normal.
    """
    result = norm.cdf(x = n, loc = mu, scale = s)

    return result

def qnorm(n, mu = 0, s = 1):
    """
    Calcula la función cuantil a partir de la distribución normal.
    """
    result = norm.ppf(q = n, loc = mu, scale = s)

    return result

def rnorm(mu = 0, s = 1, n = 1):
    """
    Calcula el acumulado de la distribución normal.
    """
    result = norm.rvs(loc = mu, scale = s, size = n)

    return result

# %%
# Distribución normal(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a normal(10, 0.2) takes the value 2: {dnorm(2, mu = 10, s = 0.2)}")
print(f"Probability that a normal(10, 0.2) will take a value less than 2: {pnorm(2, mu=10, s= 0.2)}")
print(f"Which value of a normal(10, 0.2) has a cumulative probability of 0.9? {qnorm(0.9, mu=10,  = 0.2)}")
print(f"Generate 2000 random values from a normal(10, 0.2) distribution: {rnorm(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a normal(10, 0.2) takes the value 2: 0.0
# Probability that a normal(10, 0.2) will take a value less than 2: 0.0
# Which value of a normal(10, 0.2) has a cumulative probability of 0.9? 10.25631031310892
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 9
#       7 print(f"Probability that a normal(10, 0.2) will take a value less than 2: {pnorm(2, mu=10, s= 0.2)}")
#       8 print(f"Which value of a normal(10, 0.2) has a cumulative probability of 0.9? {qnorm(0.9, mu=10, s= 0.2)}")
# ----> 9 print(f"Generate 2000 random values from a normal(10, 0.2) distribution: {rnorm(2000, loc = 10, prob = 0.2)}")
#
# TypeError: rnorm() got an unexpected keyword argument 'loc'

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

mu = 0
s = 1
data = np.linspace(-5, 5, 1000)

pmf = dnorm(data, mu = mu, s = s)
cdf = pnorm(data, mu = mu, s = s)
ppf = qnorm(data, mu = mu, s = s)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Distribución uniforme
from scipy.stats import uniform

def duniform(n, mu= 0, s = 1):
    """
    Calcula la estimación puntual de la distribución uniforme.
    """
    result = uniform.pdf(x = n, loc = mu, scale = s)

    return result

def puniform(n, mu = 0, s = 1):
    """
    Calcula el acumulado de la distribución uniforme.
    """
    result = uniform.cdf(x = n, loc = mu, scale = s)

    return result

def quniform(n, mu = 0, s = 1):
    """
    Calcula la función cuantil a partir de la distribución uniforme.
    """
    result = uniform.ppf(q = n, loc = mu, scale = s)

    return result

def runiform(mu = 0, s = 1, n = 1):
    """
    Calcula el acumulado de la distribución uniforme.
    """
    result = uniform.rvs(loc = mu, scale = s, size = n)

    return result

# %%
# Distribución uniforme(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a uniform(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a uniform(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a normal(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a uniform(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a uniform(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a uniform(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a normal(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a uniform(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

mu = 0
s = 1
data = np.linspace(-5, 5, 1000)

pmf = duniform(data, mu = mu, s = s)
cdf = puniform(data, mu = mu, s = s)
ppf = quniform(data, mu = mu, s = s)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
